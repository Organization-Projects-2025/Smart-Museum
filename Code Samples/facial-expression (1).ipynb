# %%
pip install deepface

# %%
import cv2
from deepface import DeepFace
from google.colab.patches import cv2_imshow

# %%
img_path = "/content/abba.png"
# read image
img = cv2.imread(img_path)

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=500x426>

# %%
required_outputs = ["age", "gender", "race", "emotion"]
result = DeepFace.analyze(img, actions=required_outputs)
# Out:
# Action: emotion: 100%|██████████| 4/4 [00:01<00:00,  2.93it/s]
# Action: emotion: 100%|██████████| 4/4 [00:01<00:00,  3.06it/s]
# Action: emotion: 100%|██████████| 4/4 [00:01<00:00,  3.09it/s]
# Action: emotion: 100%|██████████| 4/4 [00:01<00:00,  3.01it/s]

# %%
print(result)
# Out:
# [{'age': 32, 'region': {'x': 168, 'y': 70, 'w': 66, 'h': 66}, 'gender': {'Woman': 100.0, 'Man': 1.2890295775225269e-08}, 'dominant_gender': 'Woman', 'race': {'asian': 0.0033652987976016046, 'indian': 0.01851025660819109, 'black': 8.654328772226854e-05, 'white': 88.43472141805631, 'middle eastern': 3.9072855374472693, 'latino hispanic': 7.63602463769619}, 'dominant_race': 'white', 'emotion': {'angry': 2.2707156250786897e-11, 'disgust': 8.395247079979261e-20, 'fear': 3.006473989577464e-13, 'happy': 99.9773919582367, 'sad': 3.083545354817807e-10, 'surprise': 1.4611675758224862e-08, 'neutral': 0.022608382278122008}, 'dominant_emotion': 'happy'}, {'age': 32, 'region': {'x': 56, 'y': 55, 'w': 75, 'h': 75}, 'gender': {'Woman': 0.1661802874878049, 'Man': 99.83382225036621}, 'dominant_gender': 'Man', 'race': {'asian': 1.77552139657422e-09, 'indian': 9.178773019424824e-09, 'black': 5.433154604385718e-12, 'white': 99.99611377716064, 'middle eastern': 0.0033839940442703664, 'latino hispanic': 0.000500728674523998}, 'dominant_race': 'white', 'emotion': {'angry': 6.566390660378563e-10, 'disgust': 5.236564888669529e-16, 'fear': 1.4432254219834406e-11, 'happy': 99.99933242797852, 'sad': 1.7308319708031483e-09, 'surprise': 6.5752977321089295e-15, 'neutral': 0.0006703333383484278}, 'dominant_emotion': 'happy'}, {'age': 29, 'region': {'x': 267, 'y': 69, 'w': 87, 'h': 87}, 'gender': {'Woman': 99.99995231628418, 'Man': 5.121021899867628e-05}, 'dominant_gender': 'Woman', 'race': {'asian': 2.285040386074133e-09, 'indian': 1.94216658814389e-11, 'black': 3.4002136552186e-14, 'white': 100.0, 'middle eastern': 4.143547727153418e-06, 'latino hispanic': 3.2413591810609432e-06}, 'dominant_race': 'white', 'emotion': {'angry': 1.638584268270904e-07, 'disgust': 2.641991985428971e-12, 'fear': 5.259217106950986e-10, 'happy': 99.99903440475464, 'sad': 5.806561009791267e-07, 'surprise': 7.676045563065337e-10, 'neutral': 0.0009681267329142429}, 'dominant_emotion': 'happy'}, {'age': 30, 'region': {'x': 354, 'y': 78, 'w': 74, 'h': 74}, 'gender': {'Woman': 0.013100780779495835, 'Man': 99.98689889907837}, 'dominant_gender': 'Man', 'race': {'asian': 0.13541648645576995, 'indian': 2.000974811497353, 'black': 0.05916692193284071, 'white': 60.04559277944651, 'middle eastern': 15.308323167762378, 'latino hispanic': 22.45051742189915}, 'dominant_race': 'white', 'emotion': {'angry': 5.286478810262452e-07, 'disgust': 1.9160774486050768e-16, 'fear': 1.2101261832875299e-10, 'happy': 99.92503523826599, 'sad': 8.658826433638467e-08, 'surprise': 2.260529008424328e-06, 'neutral': 0.07496625185012817}, 'dominant_emotion': 'happy'}]

# %%
import json

print(json.dumps(result, sort_keys=True, indent=4))
# Out:
# [
#     {
#         "age": 32,
#         "dominant_emotion": "happy",
#         "dominant_gender": "Woman",
#         "dominant_race": "white",
#         "emotion": {
#             "angry": 2.2707156250786897e-11,
#             "disgust": 8.395247079979261e-20,
#             "fear": 3.006473989577464e-13,
#             "happy": 99.9773919582367,
#             "neutral": 0.022608382278122008,
#             "sad": 3.083545354817807e-10,
#             "surprise": 1.4611675758224862e-08
#         },
#         "gender": {
#             "Man": 1.2890295775225269e-08,
#             "Woman": 100.0
#         },
#         "race": {
#             "asian": 0.0033652987976016046,
#             "black": 8.654328772226854e-05,
#             "indian": 0.01851025660819109,
#             "latino hispanic": 7.63602463769619,
#             "middle eastern": 3.9072855374472693,
#             "white": 88.43472141805631
#         },
#         "region": {
#             "h": 66,
#             "w": 66,
#             "x": 168,
#             "y": 70
#         }
#     },
#     {
#         "age": 32,
#         "dominant_emotion": "happy",
#         "dominant_gender": "Man",
#         "dominant_race": "white",
#         "emotion": {
#             "angry": 6.566390660378563e-10,
#             "disgust": 5.236564888669529e-16,
#             "fear": 1.4432254219834406e-11,
#             "happy": 99.99933242797852,
#             "neutral": 0.0006703333383484278,
#             "sad": 1.7308319708031483e-09,
#             "surprise": 6.5752977321089295e-15
#         },
#         "gender": {
#             "Man": 99.83382225036621,
#             "Woman": 0.1661802874878049
#         },
#         "race": {
#             "asian": 1.77552139657422e-09,
#             "black": 5.433154604385718e-12,
#             "indian": 9.178773019424824e-09,
#             "latino hispanic": 0.000500728674523998,
#             "middle eastern": 0.0033839940442703664,
#             "white": 99.99611377716064
#         },
#         "region": {
#             "h": 75,
#             "w": 75,
#             "x": 56,
#             "y": 55
#         }
#     },
#     {
#         "age": 29,
#         "dominant_emotion": "happy",
#         "dominant_gender": "Woman",
#         "dominant_race": "white",
#         "emotion": {
#             "angry": 1.638584268270904e-07,
#             "disgust": 2.641991985428971e-12,
#             "fear": 5.259217106950986e-10,
#             "happy": 99.99903440475464,
#             "neutral": 0.0009681267329142429,
#             "sad": 5.806561009791267e-07,
#             "surprise": 7.676045563065337e-10
#         },
#         "gender": {
#             "Man": 5.121021899867628e-05,
#             "Woman": 99.99995231628418
#         },
#         "race": {
#             "asian": 2.285040386074133e-09,
#             "black": 3.4002136552186e-14,
#             "indian": 1.94216658814389e-11,
#             "latino hispanic": 3.2413591810609432e-06,
#             "middle eastern": 4.143547727153418e-06,
#             "white": 100.0
#         },
#         "region": {
#             "h": 87,
#             "w": 87,
#             "x": 267,
#             "y": 69
#         }
#     },
#     {
#         "age": 30,
#         "dominant_emotion": "happy",
#         "dominant_gender": "Man",
#         "dominant_race": "white",
#         "emotion": {
#             "angry": 5.286478810262452e-07,
#             "disgust": 1.9160774486050768e-16,
#             "fear": 1.2101261832875299e-10,
#             "happy": 99.92503523826599,
#             "neutral": 0.07496625185012817,
#             "sad": 8.658826433638467e-08,
#             "surprise": 2.260529008424328e-06
#         },
#         "gender": {
#             "Man": 99.98689889907837,
#             "Woman": 0.013100780779495835
#         },
#         "race": {
#             "asian": 0.13541648645576995,
#             "black": 0.05916692193284071,
#             "indian": 2.000974811497353,
#             "latino hispanic": 22.45051742189915,
#             "middle eastern": 15.308323167762378,
#             "white": 60.04559277944651
#         },
#         "region": {
#             "h": 74,
#             "w": 74,
#             "x": 354,
#             "y": 78
#         }
#     }
# ]
